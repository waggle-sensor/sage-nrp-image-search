# %% [markdown]
# # This Notebook is Archived!! Check the new one in the overall folder

# %% [markdown]
# # Libraries

# %%
import sys
from pathlib import Path

# Add benchmarking dir so helpers.plot is importable
_bench = Path.cwd().parents[1]
sys.path.insert(0, str(_bench))

from benchmarking.helpers.plot import plot_overall_hitrate, plot_overall_ndcg, plot_overall_diversity, plot_overall_mrr

# %% [markdown]
# # Evaluating ALL Benchmarks
#
# Here we will evaluate the raw query metrics returned by all benchmarks based on the system version.

# %% [markdown]
# ## Overall Hit Rate Across Benchmarks
#
# Hit rate (Success@25) = fraction of queries with at least one relevant image in the top 25.

# %%
plot_overall_hitrate(
    system_version="v10",
    base_path=Path.cwd(),
    benchmarks=["INQUIRE", "Firebench", "Commonobjectsbench", "Cloudbench"],
    response_limit=25
)

# %% [markdown]
# ## Overall Diversity Across Benchmarks
#
# Diversity measures the diversity of the retrieved images; higher means more diverse images are retrieved.

# %%
plot_overall_diversity(
    system_version="v10",
    base_path=Path.cwd(),
    benchmarks=["INQUIRE", "Firebench", "Commonobjectsbench", "Cloudbench"],
)

# %% [markdown]
# ## Overall MRR Across Benchmarks
#
# MRR (Mean Reciprocal Rank) measures how early the first relevant result appears.

# %%
plot_overall_mrr(
    system_version="v10",
    base_path=Path.cwd(),
    benchmarks=["INQUIRE", "Firebench", "Commonobjectsbench", "Cloudbench"],
)

# %% [markdown]
# ## Overall NDCG Across Benchmarks
#
# NDCG (Normalized Discounted Cumulative Gain) measures ranking quality; higher means relevant images are ranked higher.

# %%
plot_overall_ndcg(
    system_version="v10",
    base_path=Path.cwd(),
    benchmarks=["INQUIRE", "Firebench", "Commonobjectsbench", "Cloudbench"],
)
